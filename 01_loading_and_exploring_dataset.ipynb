# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/harpreetsahota204/car_dd_dataset_workshop/blob/main/01_loading_and_exploring_dataset.ipynb)
#
# Note: If using in Google Colab, make sure you [install all the requirements listed here](https://github.com/harpreetsahota204/car_dd_dataset_workshop/blob/main/requirements.txt).
#
# Which you can do by running the following:
#
# ```
# # Install requirements directly from the URL
# !pip install -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt
# ```
#
# You'll also want to connect to a GPU runtime.
#
# # Download dataset from source
#
# We can download the file from Google Drive using `gdown`

# %%
# !pip install -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt
# Out:
# Collecting fiftyone (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading fiftyone-1.15.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.12/dist-packages (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 3)) (2.0.11)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (2.10.0+cu128)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 5)) (5.2.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (5.0.0)
# Collecting open-clip-torch (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 7))
#   Downloading open_clip_torch-3.3.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 8)) (1.13.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 9)) (0.8.2)
# Collecting pyvips-binary (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 10))
#   Downloading pyvips_binary-8.18.2-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting pyvips (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 11))
#   Downloading pyvips-3.1.1.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 12)) (11.3.0)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.12/dist-packages (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 13)) (0.5.12)
# Collecting ultralytics (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 14))
#   Downloading ultralytics-8.4.51-py3-none-any.whl.metadata (36 kB)
# Collecting qwen-vl-utils (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 15))
#   Downloading qwen_vl_utils-0.0.14-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: hf-xet in /usr/local/lib/python3.12/dist-packages (from -r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 16)) (1.4.3)
# Collecting Deprecated (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (26.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: aiofiles<26,>=20 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (24.1.0)
# Collecting argcomplete<4,>=2 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading argcomplete-3.6.3-py3-none-any.whl.metadata (16 kB)
# Collecting async_lru<3,>=2 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: beautifulsoup4<5,>=2 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (4.13.5)
# Collecting boto3<2,>=1 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading boto3-1.43.9-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: cachetools<7,>=5 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (6.2.6)
# Collecting dacite<2,>=1.6.0 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: dill<0.5,>=0.1 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (0.3.8)
# Collecting exceptiongroup<2,>=1 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting ftfy<7,>=4 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: humanize<5,>=2 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (4.15.0)
# Collecting hypercorn<0.19,>=0.13.2 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading hypercorn-0.18.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: Jinja2<4,>=3 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: jsonpatch<2,>=1 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (1.33)
# Collecting mongoengine~=0.29.1 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading mongoengine-0.29.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting motor~=3.6.0 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading motor-3.6.1-py3-none-any.whl.metadata (21 kB)
# Collecting plotly<7,>=6.1.1 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading plotly-6.7.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pprintpp<0.5,>=0.1 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Collecting protobuf==6.33.5 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: psutil<8,>=5 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (5.9.5)
# Collecting pydash<9,>=6 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading pydash-8.0.6-py3-none-any.whl.metadata (3.4 kB)
# Collecting pymongo~=4.9.2 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading pymongo-4.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: PyYAML<7,>=4 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2025.11.3)
# Collecting retrying<2,>=1 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting sseclient-py<2,>=1.7.2 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading sseclient_py-1.9.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: sse-starlette<4,>=0.10.3 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (3.3.4)
# Requirement already satisfied: starlette<0.53,>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (0.52.1)
# Collecting strawberry-graphql<0.292.0,>=0.262.4 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading strawberry_graphql-0.291.3-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: tabulate<0.10,>=0.7 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: tqdm<5,>=2 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (4.67.3)
# Collecting xmltodict<2,>=1 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Collecting universal-analytics-python3<2,>=1.0.1 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading universal_analytics_python3-1.1.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: opencv-python-headless<5 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (4.13.0.92)
# Requirement already satisfied: pandas<4 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: rtree<2 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (1.6.1)
# Requirement already satisfied: scikit-image<1 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (0.25.2)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.12/dist-packages (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (1.16.3)
# Collecting fiftyone-brain<0.22,>=0.21.6 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading fiftyone_brain-0.21.6-py3-none-any.whl.metadata (5.2 kB)
# Collecting fiftyone-db<2.0,>=0.4 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading fiftyone_db-1.4.1.tar.gz (8.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting voxel51-eta<0.16,>=0.15.3 (from fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading voxel51_eta-0.15.5-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 5)) (2.32.4)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (1.11.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from open-clip-torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 7)) (0.25.0+cu128)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from open-clip-torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 7)) (1.0.26)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyvips-binary->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 13)) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 14)) (4.13.0.92)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 14)) (1.35.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 14))
#   Downloading ultralytics_thop-2.0.19-py3-none-any.whl.metadata (14 kB)
# Collecting av (from qwen-vl-utils->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 15))
#   Downloading av-17.0.1-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=2->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2.8.3)
# Collecting botocore<1.44.0,>=1.43.9 (from boto3<2,>=1->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading botocore-1.43.9-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2,>=1->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.18.0,>=0.17.0 (from boto3<2,>=1->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading s3transfer-0.17.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.0->pyvips-binary->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 10)) (3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy<7,>=4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (0.24.2)
# Requirement already satisfied: h11 in /usr/local/lib/python3.12/dist-packages (from hypercorn<0.19,>=0.13.2->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: h2>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from hypercorn<0.19,>=0.13.2->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (4.3.0)
# Collecting priority (from hypercorn<0.19,>=0.13.2->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading priority-2.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wsproto>=0.14.0 (from hypercorn<0.19,>=0.13.2->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2<4,>=3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2,>=1->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 13)) (0.43.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2026.1)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly<7,>=6.1.1->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 14)) (1.35.2)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo~=4.9.2->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pynndescent>=0.5->umap-learn->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 13)) (1.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 5)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 5)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 5)) (2026.4.22)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (0.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: anyio>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from sse-starlette<4,>=0.10.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (4.13.0)
# Collecting cross-web>=0.4.0 (from strawberry-graphql<0.292.0,>=0.262.4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading cross_web-0.6.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting graphql-core<3.4.0,>=3.2.0 (from strawberry-graphql<0.292.0,>=0.262.4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading graphql_core-3.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (0.7)
# Collecting jsonlines (from voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting paramiko<4,>=3 (from voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading paramiko-3.5.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting py7zr (from voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading py7zr-1.1.0-py3-none-any.whl.metadata (17 kB)
# Collecting rarfile (from voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (5.3.1)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from Deprecated->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 5)) (1.7.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2>=4.3.0->hypercorn<0.19,>=0.13.2->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2>=4.3.0->hypercorn<0.19,>=0.13.2->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (1.0.9)
# Collecting bcrypt>=3.2 (from paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: cryptography>=3.3 in /usr/local/lib/python3.12/dist-packages (from paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (43.0.3)
# Collecting pynacl>=1.5 (from paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (26.1.0)
# Collecting texttable (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: pycryptodomex>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: brotli>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1)) (1.2.0)
# Collecting backports.zstd>=1.0.0 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading backports_zstd-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.8 kB)
# Collecting pyppmd>=1.3.1 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading pyppmd-1.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting pybcj>=1.0.6 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading pybcj-1.0.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.9 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64>=1.0.4 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 1))
#   Downloading inflate64-1.0.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->-r https://raw.githubusercontent.com/harpreetsahota204/car_dd_dataset_workshop/refs/heads/main/requirements.txt (line 6)) (0.1.2)
# Downloading fiftyone-1.15.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 91.9 MB/s eta 0:00:00
# Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.5/323.5 kB 32.5 MB/s eta 0:00:00
# Downloading open_clip_torch-3.3.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 84.5 MB/s eta 0:00:00
# Downloading pyvips_binary-8.18.2-cp37-abi3-manylinux_2_28_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 110.2 MB/s eta 0:00:00
# Downloading ultralytics-8.4.51-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 85.7 MB/s eta 0:00:00
# Downloading qwen_vl_utils-0.0.14-py3-none-any.whl (8.1 kB)
# Downloading argcomplete-3.6.3-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 4.7 MB/s eta 0:00:00
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading boto3-1.43.9-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 15.7 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading fiftyone_brain-0.21.6-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 kB 14.2 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.1 MB/s eta 0:00:00
# Downloading hypercorn-0.18.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.6 MB/s eta 0:00:00
# Downloading mongoengine-0.29.3-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 12.7 MB/s eta 0:00:00
# Downloading motor-3.6.1-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 9.0 MB/s eta 0:00:00
# Downloading plotly-6.7.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 107.6 MB/s eta 0:00:00
# Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Downloading pydash-8.0.6-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 12.4 MB/s eta 0:00:00
# Downloading pymongo-4.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 98.0 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading sseclient_py-1.9.0-py3-none-any.whl (8.4 kB)
# Downloading strawberry_graphql-0.291.3-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.4/316.4 kB 32.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.19-py3-none-any.whl (28 kB)
# Downloading universal_analytics_python3-1.1.1-py3-none-any.whl (10 kB)
# Downloading voxel51_eta-0.15.5-py2.py3-none-any.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.9/935.9 kB 68.1 MB/s eta 0:00:00
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Downloading av-17.0.1-cp311-abi3-manylinux_2_28_x86_64.whl (36.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 22.7 MB/s eta 0:00:00
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading botocore-1.43.9-py3-none-any.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 96.5 MB/s eta 0:00:00
# Downloading cross_web-0.6.0-py3-none-any.whl (24 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 25.4 MB/s eta 0:00:00
# Downloading graphql_core-3.2.8-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 24.0 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading paramiko-3.5.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 24.8 MB/s eta 0:00:00
# Downloading s3transfer-0.17.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.5 MB/s eta 0:00:00
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Downloading py7zr-1.1.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.3/71.3 kB 8.7 MB/s eta 0:00:00
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Downloading backports_zstd-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (495 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.3/495.3 kB 40.2 MB/s eta 0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 30.6 MB/s eta 0:00:00
# Downloading inflate64-1.0.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 12.4 MB/s eta 0:00:00
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading pybcj-1.0.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 5.8 MB/s eta 0:00:00
# Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 72.1 MB/s eta 0:00:00
# Downloading pyppmd-1.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 17.6 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: pyvips, fiftyone-db
#   Building wheel for pyvips (pyproject.toml) ... done
#   Created wheel for pyvips: filename=pyvips-3.1.1-py3-none-any.whl size=54328 sha256=5c4c624dadce5688131af1a002ac5ab9a71188a18f6288d8dad60e9d4bfe4b22
#   Stored in directory: /root/.cache/pip/wheels/9f/53/c8/230d343a3109d13b33cf2c2cf2ac7f361c640152974627663e
#   Building wheel for fiftyone-db (pyproject.toml) ... done
#   Created wheel for fiftyone-db: filename=fiftyone_db-1.4.1-py3-none-manylinux1_x86_64.whl size=50655255 sha256=8ee44b2a470a002abd01b7f4d68e8c43e2671714d09fb74ffe94905dac97f4bd
#   Stored in directory: /root/.cache/pip/wheels/fc/06/06/0eb7530b99c4934bf36390769cff3f0052fd04f50f390d5c8b
# Successfully built pyvips fiftyone-db
# Installing collected packages: texttable, pprintpp, xmltodict, wsproto, sseclient-py, retrying, rarfile, pyppmd, pydash, pybcj, protobuf, priority, plotly, multivolumefile, jsonlines, jmespath, inflate64, graphql-core, ftfy, fiftyone-db, exceptiongroup, dnspython, Deprecated, dacite, cross-web, bcrypt, backports.zstd, av, async_lru, argcomplete, strawberry-graphql, qwen-vl-utils, pyvips-binary, pyvips, pynacl, pymongo, py7zr, hypercorn, botocore, universal-analytics-python3, s3transfer, paramiko, motor, mongoengine, fiftyone-brain, voxel51-eta, ultralytics-thop, boto3, ultralytics, fiftyone, open-clip-torch
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.5 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.5 which is incompatible.
# Successfully installed Deprecated-1.3.1 argcomplete-3.6.3 async_lru-2.3.0 av-17.0.1 backports.zstd-1.5.0 bcrypt-5.0.0 boto3-1.43.9 botocore-1.43.9 cross-web-0.6.0 dacite-1.9.2 dnspython-2.8.0 exceptiongroup-1.3.1 fiftyone-1.15.0 fiftyone-brain-0.21.6 fiftyone-db-1.4.1 ftfy-6.3.1 graphql-core-3.2.8 hypercorn-0.18.0 inflate64-1.0.4 jmespath-1.1.0 jsonlines-4.0.0 mongoengine-0.29.3 motor-3.6.1 multivolumefile-0.2.3 open-clip-torch-3.3.0 paramiko-3.5.1 plotly-6.7.0 pprintpp-0.4.0 priority-2.0.0 protobuf-6.33.5 py7zr-1.1.0 pybcj-1.0.7 pydash-8.0.6 pymongo-4.9.2 pynacl-1.6.2 pyppmd-1.3.1 pyvips-3.1.1 pyvips-binary-8.18.2 qwen-vl-utils-0.0.14 rarfile-4.2 retrying-1.4.2 s3transfer-0.17.0 sseclient-py-1.9.0 strawberry-graphql-0.291.3 texttable-1.7.0 ultralytics-8.4.51 ultralytics-thop-2.0.19 universal-analytics-python3-1.1.1 voxel51-eta-0.15.5 wsproto-1.3.2 xmltodict-1.0.4

# %%
import gdown

# Download the CarDD dataset from Google Drive
url = "https://drive.google.com/uc?id=1RgiZK970s0BffZiAkwmxrdJ7klqIY2PZ"
gdown.download(url, output="cardd.zip", quiet=False)

# %% [markdown]
# You can then extract the dataset as follows:

# %%
# !unzip cardd.zip

# %% [markdown]
# ### Load into FiftyOne Format
#
# FiftyOne [supports importing datasets from disk in various formats](https://docs.voxel51.com/user_guide/import_datasets.html), and it can be extended to import datasets in custom formats. The basic recipe involves specifying the path(s) to the data on disk and the type of dataset you’re loading.
#
# You can import a dataset from disk via [the `from_dir()` method](https://docs.voxel51.com/api/fiftyone.core.dataset.html#fiftyone.core.dataset.Dataset).
#
# Read the docs for full detail on all [supported formats](https://docs.voxel51.com/user_guide/import_datasets.html#built-in-formats).
#
# The CarDD dataset is in COCO format, so you can use [FiftyOne's built-in importer for COCO dataset](https://docs.voxel51.com/api/fiftyone.types.html#fiftyone.types.COCODetectionDataset).
#
# The relevant arguments we use here are:
#
# • `data_path` - where the images reside on disk
#
# • `labels_path` - the path to the annotations, which should be a `json` file
#
# • `dataset_type` - let' FiftyOne know we are loading a Dataset in COCO format
#
# Read [the docs to learn more](https://docs.voxel51.com/api/fiftyone.utils.coco.html#fiftyone.utils.coco.COCODetectionDatasetImporter) about working with datasets in COCO format.

# %%
import fiftyone as fo

dataset = fo.Dataset.from_dir(
    data_path="CarDD_release/CarDD_COCO/train2017",
    labels_path="CarDD_release/CarDD_COCO/annotations/instances_train2017.json",
    dataset_type=fo.types.COCODetectionDataset,
    name="car_dd",
    overwrite=True,
    include_id=True,
)

# %% [markdown]
# You can call the dataset to see it's associated fields:

# %%
dataset

# %% [markdown]
# Let's [persist the Dataset](https://docs.voxel51.com/user_guide/using_datasets.html#dataset-persistence) as non-persistent datasets are deleted from the database each time the database is shut down. Note, you could define dataset persistence when you create the dataset by passing `persistent=True` into the `from_dir` method above.

# %%
dataset.persistent = True

# %% [markdown]
# You can also call [the first Sample of the Dataset](https://docs.voxel51.com/api/fiftyone.core.dataset.html#fiftyone.core.dataset.Dataset) to see what the Fields looks like:

# %%
dataset.first()

# %% [markdown]
# Notice that bounding box detections and the segmentations are parsed as [FiftyOne Detection types](https://docs.voxel51.com/api/fiftyone.core.labels.html#fiftyone.core.labels.Detection).
#
# FiftyOne Detections are relative bounding box coordinates in `[0, 1]` in the following format: `[top-left-x, top-left-y, width, height]`.
#
#
#
# Since we are working with instance segmentation the labels are parsed via the Detection label type with `mask` defining an instance segmentation mask for the detection within its bounding box. These are parsed as a 2D binary or 0/1 integer `numpy` array.
#
# # Alternatively, download dataset from Hugging Face Hub
#
# FiftyOne has an [integration with Hugging Face](https://docs.voxel51.com/integrations/huggingface.html), which allows you to push and pull FiftyOne Datasets from the Hugging Face Hub.
#
# For the purposes of this workshop, I have have already [parsed this dataset into FiftyOne format and pushed it to the Hub](https://huggingface.co/datasets/harpreetsahota/CarDD).
#
# You can download it as follows:

# %%
import fiftyone as fo
from fiftyone.utils.huggingface import load_from_hub

dataset = load_from_hub(
    "harpreetsahota/CarDD",
    name="cardd_from_hub",
    # max_samples=500, # if you want to work with a subset of the dataset
    persistent=True,
    overwrite=True,
    )

# %% [markdown]
# # [Optional] Using thumnails in the app
#
# To use thumbnails in the FiftyOne App (for faster grid rendering), create downscaled images, store their paths on each sample, and configure the dataset’s App config to show them in the grid while keeping full-res media in the modal.

# %%
import fiftyone as fo
import fiftyone.utils.image as foui

# 1) Generate thumbnails and store paths in a field (e.g. "thumbnail_path")
foui.transform_images(
    dataset,
    size=(-1, 256),                 # preserve aspect ratio; height=256px
    output_field="thumbnail_path",  # where to store the thumbnail path
    output_dir="thumbnails",
    skip_failures=True,
)

# 2) Configure the App to use the thumbnail field in the grid
dataset.app_config.media_fields = ["filepath", "thumbnail_path"]
dataset.app_config.grid_media_field = "thumbnail_path"
dataset.save()  # persist the App config change

# %% [markdown]
# With your Dataset loaded into FiftyOne format, now is a good time to launch the App and perform a "visual vibe check" of its contents.
#
# You can launch the app in a notebook by running:
#
# ```python
#
# import fiftyone as fo
#
# fo.launch_app(hub_dataset)
# ```
#
# Or, you can open your terminal and execute `fiftyone app launch`. This will open the App in a browser window, and you can select your Dataset from the dropdown menu.
#
# # Exploration via FiftyOne App
#
# You can use the App in a variety of ways to explore your Dataset. One way to do this is by making using of [the Dashboard plugin](https://github.com/voxel51/fiftyone-plugins/tree/main/plugins/dashboard), which allows you to create interactive dashboards and explore the Dataset in detail.
#
# We'll discuss [using and developing plugins](https://docs.voxel51.com/plugins/index.html#plugins-overview) later in this workshop, but for now let's go ahead and install the required plugin:

# %%
# !fiftyone plugins download \
    https://github.com/voxel51/fiftyone-plugins \
    --plugin-names @voxel51/dashboard

# %% [markdown]
# ### Initial exploration via SDK
#
# > If you're a seasoned Pandas user, you might want to learn more about performing Pandas-style queries in FiftyOne. Read [these docs to learn more](https://docs.voxel51.com/cheat_sheets/pandas_vs_fiftyone.html).
#
# Let's explore the Dataset via the SDK before launching the FiftyOne App. From here on out, we will make use of the dataset that we have downloaded from the Hugging Face Hub
#
# You'll make use of a [`ViewExpression`](https://docs.voxel51.com/api/fiftyone.core.expressions.html#fiftyone.core.expressions.ViewExpression) and [`ViewField`](https://docs.voxel51.com/api/fiftyone.core.expressions.html#fiftyone.core.expressions.ViewField) to perform aggregrations over fields of a FiftyOne dataset. Using `ViewField` allows efficient calculation across the entire dataset without manual iteration.
#
# You can learn more about aggregrations in FiftyOne by [reading these docs](https://docs.voxel51.com/api/fiftyone.core.aggregations.html#module-fiftyone.core.aggregations) and learn more about creating `Views` in [these docs](https://docs.voxel51.com/user_guide/using_views.html) or read the [Views Cheat Sheet](https://docs.voxel51.com/cheat_sheets/views_cheat_sheet.html).
#
# Let's see the counts and types of damages in this dataset:

# %%
from fiftyone import ViewField as F

dataset.count_values(F"detections.detections.label")

# %% [markdown]
# ### Enriching the dataset
#
# You notice that beyond the bounding boxes and segmentation masks, there is not much other information on this dataset. However, you can use Fiftyone to enrich your dataset.
#
# Something you might be interested in is the are of the bounding boxes. Let's start by adding this information. The code below will help us compute this value. Here's what is happening:
#
# - `rel_bbox_area`: Calculates bounding box area (width * height) as fraction of image size
#
# - `im_width, im_height`: Gets image dimensions from metadata
#
# - `abs_area`: Converts relative area to pixels by multiplying with image dimensions
#
# The code adds two fields to each detection:
#
# 1. `relative_bbox_area`: Area as fraction of image (0-1). Note: represent the percentage of the total image area.
#
# 2. `absolute_bbox_area`: Area in pixels

# %%
from fiftyone import ViewField as F

rel_bbox_area = F("bounding_box")[2] * F("bounding_box")[3]

im_width, im_height = F("$metadata.width"), F("$metadata.height")

abs_area = rel_bbox_area * im_width * im_height

dataset.set_field("detections.detections.relative_bbox_area", rel_bbox_area).save()

dataset.set_field("detections.detections.absolute_bbox_area", abs_area).save()

# %% [markdown]
# With these values computed you can perform some useful aggregations, for example you  can compute the [upper and lower bounds of the bounding box areas](https://docs.voxel51.com/api/fiftyone.core.aggregations.html#fiftyone.core.aggregations.Bounds) as well as other summary statistics like mean and standard deviation.
#
# This code performs analysis on a car damage dataset (CarDD) loaded into FiftyOne. For each damage type (like "scratch", "dent", "crack", etc.), it:
#
# 1. Creates a filtered view containing only detections with that specific label
# 2. Calculates bounds (min/max) of the bounding box areas as percentage of image size
# 3. Computes the mean area and standard deviation
# 4. Formats and prints a summary showing the distribution of bounding box sizes for each damage type
#
# This helps understand the relative size characteristics of different damage types - for instance, whether scratches tend to be smaller or larger than dents, which types have more size variation, and what the extreme values look like across the dataset.

# %%
labels = dataset.distinct("detections.detections.label")

for label in labels:
    view = dataset.filter_labels("detections", F("label") == label)
    bounds = view.bounds("detections.detections.relative_bbox_area")
    bounds = (bounds[0]*100, bounds[1]*100)
    area = view.mean("detections.detections.relative_bbox_area")*100
    std = view.std("detections.detections.relative_bbox_area")
    print("\033[1m%s:\033[0m Min: %.4f, Mean: %.4f, Std: %.4f, Max: %.4f" % (label, bounds[0], std, area, bounds[1]))

# %% [markdown]
# In the context of the CarDD damage dataset, this analysis is useful because:
#
# 1. It helps understand the physical characteristics of different damage types - scratches might be long and thin, while dents could be more compact
#
# 2. It identifies potential challenges for damage detection models - very small damages might be harder to detect
#
# 3. It can inform model architecture decisions - if damage sizes vary dramatically, you might need a model that handles multi-scale features well
#
# 4. It helps with data filtering and subset creation - you could focus on smaller damages for fine-grained detection tasks
#
# 5. It provides dataset quality insights - unusually large or small annotations might indicate labeling errors
#
# 6. It enables more targeted data augmentation - you could apply transformations specifically for damage types with limited size variations
#
# This size distribution knowledge ultimately helps build more robust computer vision models for vehicle damage assessment.

# %% [markdown]
# You can also filter to Samples which have a scratch which meets some condition (as defined by their relative bounding box areas):

# %%
from fiftyone import ViewField as F

filter_to_scratch = F("label") == "scratch"

filter_to__boxes = F("relative_bbox_area") < 0.03

filtered_scratches = dataset.match_labels(
    filter=(filter_to_scratch & filter_to_scratch),
    fields="detections.detections"
    )

# %% [markdown]
# You'll see that we have just created a View into our dataset:

# %%
type(filtered_scratches)

# %% [markdown]
# You can save this view to the Dataset so that you can visualize them later in the FiftyOne App:

# %%
dataset.save_view("filtered_scratches", filtered_scratches)

# %% [markdown]
# If, for whatever reason, you want to delete a View you can run:
#
# ```python
# hub_dataset.delete_saved_view("<view-name>")
# ```
#
# Or delete all the saved Views as follows:
#
# ```python
# hub_dataset.delete_saved_views()
# ```
#
#
# > Check out [this tutorial for more information](https://github.com/harpreetsahota204/Hands-on-Data-Centric-Visual-AI/blob/main/Module-2/Lesson_1_Exploring_Your_Dataset_with_FiftyOne.ipynb) about doing complex aggregations and filtering in FiftyOne

# %% [markdown]
# ### Computing surface area of damages
#
# This code takes a dataset of car damage images with their associated damage annotations and converts their representation into a more useful format.
#
# 1. First, it extracts all the ground truth detection masks from the dataset using the [`values` method](https://docs.voxel51.com/api/fiftyone.core.dataset.html#fiftyone.core.dataset.Dataset.values) of the Dataset.
#
# 2. It then prepares to convert these masks into a [FiftyOne Polyline](https://docs.voxel51.com/api/fiftyone.core.labels.html#fiftyone.core.labels.Polyline), which are essentially outlines of the damaged areas defined by a series of connected points.
#
# 3. The code then goes through each image's detections one by one:
#    - For each image that has damage annotations, it converts all the damage masks into a FiftyOne Polyline.
#    - If an image has no damage annotations, it creates an empty list instead
#    - It packages these polylines into a [FiftyOne Polylines](https://docs.voxel51.com/api/fiftyone.core.labels.html#fiftyone.core.labels.Polyline), which is just a a list of Polylines or polygons in an image.
#
# 4. Finally, it adds all these polyline representations back to the dataset as a new field called `polylines`.
#
# This conversion is useful because polylines can be easier to work with for certain types of analysis, like calculating the area of damaged regions or visualizing the boundaries of damage. It's like having both a coloring book (the masks) and just the outlines (the polylines) - each format has its own advantages for different tasks.

# %%
# Get all ground truth detection masks from the dataset
# This returns a list of Detections objects, one per sample
segmentation_masks = dataset.values("segmentations.detections")

# Initialize an empty list to store polyline representations for each sample
all_polylines = []

# Iterate through detections for each sample in the dataset
for sample_segmentation in segmentation_masks:
    # For each detection in the sample, convert its segmentation mask to a polyline
    # If sample has no detections (None), create empty list
    polylines = [segmentation.to_polyline() for segmentation in sample_segmentation] if sample_segmentation else []

    # Create a FiftyOne Polylines field containing the polyline representations
    polylines_field = fo.Polylines(
        polylines=polylines,
        closed=True,
        filled=True,
        )

    # Add the polylines for this sample to our list
    all_polylines.append(polylines_field)

# Add the polylines field to every sample in the dataset
# This creates a new field called "polylines" containing the polyline representations
dataset.set_values("polylines", all_polylines)

# %% [markdown]
# Now we can define a function which will compute the area of a polygon:

# %%
import numpy as np

def compute_polygon_area(points, image_width, image_height):
    """
    Compute the area of a polygon in pixel units using the Shoelace formula.

    Args:
        points: List of (x,y) coordinates defining the polygon vertices, normalized to [0,1]
        image_width: Width of the image in pixels
        image_height: Height of the image in pixels

    Returns:
        float: Area of the polygon in square pixels

    Notes:
        The Shoelace formula (also known as the surveyor's formula) calculates the area
        of a polygon by using the coordinates of its vertices. The formula gets its name
        from the way the computation "laces" together vertex coordinates.
    """
    # Convert points list to numpy array for vectorized operations
    points = np.array(points)

    # Scale normalized coordinates back to pixel dimensions
    points[:, 0] *= image_width  # Scale x coordinates
    points[:, 1] *= image_height # Scale y coordinates

    # Extract x and y coordinates into separate arrays
    x = points[:, 0]
    y = points[:, 1]

    # Create shifted versions of coordinate arrays
    # np.roll shifts array elements by 1 position for the formula
    x_shift = np.roll(x, 1)
    y_shift = np.roll(y, 1)

    # Apply Shoelace formula: A = 1/2 * |sum(x_i*y_i+1 - x_i+1*y_i)|
    return 0.5 * np.abs(np.sum(x * y_shift - x_shift * y))

# %% [markdown]
# Finally, we can add in the absolute and relative surface areas.
#
# This code processes each sample in a car damage dataset to calculate the surface area of the damage regions. For each sample:
#
# 1. It extracts the polygon coordinates (`points`) from the first polyline in the sample. These polylines represent the outlines of damaged areas on the car.
#
# 2. It retrieves the image dimensions (`width` and `height`) from the sample's metadata.
#
# 3. It calculates the `absolute_surface_area` of the damage in pixels using a helper function called `compute_polygon_area`, which likely uses the Shoelace formula to calculate the area of an irregular polygon.
#
# 4. It calculates the `relative_surface_area` as a proportion of the total image area, but there's a bug: it uses an undefined variable `area` instead of `absolute_surface_area`.
#
# 5. It adds both measurements as properties to the polyline object.
#
# 6. It saves the updated sample back to the dataset.
#
# This information is valuable for analyzing damage severity and comparing different types of damage across the dataset.

# %%
import numpy as np

for sample in dataset:
    # Get the points - take the first list from the nested structure
    points = np.array(sample.polylines.polylines[0].points[0])  # Note the [0] to get first list

    # Get image dimensions
    width = sample.metadata.width
    height = sample.metadata.height

    # Compute area using the helper function
    absolute_surface_area = compute_polygon_area(points, width, height)

    relative_surface_area = area / (width * height)

    # Store both relative and absolute areas
    sample.polylines.polylines[0].relative_surface_area = relative_surface_area
    sample.polylines.polylines[0].absolute_surface_area = absolute_surface_area

    # Save the sample
    sample.save()

# %% [markdown]
# This code analyzes the distribution of damage sizes for each damage type in a vehicle damage dataset using FiftyOne. It:
#
# 1. Gets all unique damage labels from the polylines field
# 2. For each damage type, creates a filtered view containing only that type
# 3. Calculates size statistics (minimum, maximum, mean, standard deviation)
# 4. Formats and prints these statistics with the damage type in bold
#
# This helps understand the relative size characteristics of different damage types (scratches, dents, etc.), which is valuable for training detection models and understanding dataset properties.

# %%
dataset.first()['polylines']

# %% [markdown]
# We'll want to be able to use these area's so we need [add dynamic sample fields](https://docs.voxel51.com/api/fiftyone.core.dataset.html#fiftyone.core.dataset.Dataset.add_dynamic_sample_fields):

# %%
dataset.add_dynamic_sample_fields()

# %% [markdown]
# ### Using VLMs for data enrichment
#
# #### Note: This section requires access to a GPU and runtime may be long
#
# You can download a dataset with these results via:
#
# ```python
#
# # # or if you are in a new notebook
# import fiftyone as fo
# from fiftyone.utils.huggingface import load_from_hub
#
# dataset = load_from_hub(
#     "harpreetsahota/cardd_workshop_post_01",
#     overwrite=True
#     )
#
# dataset.persistent=True
# ```
#
# This will take an additional ~6GB of diskspace. If you're limited on diskspace, you can `CarDD_Release` folder you unzipped earlier in this lesson.
#
# ### You can use Vision Language Models (VLMs) to enrich car damage analysis in some interesting ways:
#
# 1. **Basic Captioning:** Generate descriptions of damage type, severity, and affected car parts in natural language.
#
# 2. **Detailed Location:** Convert basic annotations (like "dent on door") into precise descriptions (like "dent on lower passenger door near handle").
#
# 3. **Damage Cause Analysis:** Infer potential causes from visual clues (e.g., "scratch likely from brushing against object").
#
# 4. **Scene Context:** Describe relevant environmental factors (e.g., "parked car, daylight conditions, clean vehicle").
#
# 5. **Multi-Damage Relations:** Explain how multiple damages relate (e.g., "scratch running across dent" or "cluster of dents").
#
# 6. **Component Recognition:** Identify and label both damaged and undamaged car parts for better context.
#
#
# FiftyOne allows you to use VLMs rather seemlessly, for example [MiniCPM is a VLM](https://github.com/harpreetsahota204/minicpm-v) which has been integrated as a [Remotely Sourced Zoo Model](https://docs.voxel51.com/model_zoo/remote.html) (which we will discuss later).
#
# Start by registering the model:

# %%
import fiftyone.zoo as foz

foz.register_zoo_model_source(
    "https://github.com/harpreetsahota204/minicpm-v",
    overwrite=True
)

# %%
foz.download_zoo_model(
    "https://github.com/harpreetsahota204/minicpm-v",
    model_name= "openbmb/MiniCPM-V-4_5",
    overwrite=True
)

# %% [markdown]
# Next, you can download a checkpoint. Refer to the [MiniCPM's Remote Zoo Model's GitHub](https://github.com/harpreetsahota204/minicpm-v) to see the available checkpoints.

# %% [markdown]
# Then you can load the model as you would any [Built-in Zoo Model](https://docs.voxel51.com/model_zoo/models.html).
#
# Ttart by setting `operation="vqa"`, which we will use to generate answers/captions for each image:

# %%
import fiftyone.zoo as foz

zoo_model = foz.load_zoo_model(
    "openbmb/MiniCPM-V-4_5",
    # install_requirements=True #if you are using for the first time and need to download reuirement,
    # ensure_requirements=True #  ensure any requirements are installed before loading the model
)

# %% [markdown]
# You can set the prompt for the model by as follows:

# %%
zoo_model.operation="vqa"
zoo_model.prompt="Complete a brief damage report for this vehicle in this image. Include details about the damage, including the location and type of damage. If there is no damage, say 'No damage'."

# %% [markdown]
# And then apply the model to your Dataset via [the `apply_model` method](https://docs.voxel51.com/api/fiftyone.core.models.html#fiftyone.core.models.apply_model) of the Dataset.
#
# Image captioning/VQA typically takes longer other operations.
#
# <div class="alert alert-warning">
# <strong>Warning:</strong> Image captioning/VQA operations can take a significant amount of time to complete, especially for large datasets. Please be patient while the model processes each image.
# </div>

# %%
dataset.apply_model(zoo_model, label_field="damage_report")

# %% [markdown]
# You can also use the model for classification, for example to get the color of the vehicle. All you have to do is:

# %%
zoo_model.operation="classify"
zoo_model.prompt = "What is the color of the damaged vehicle in this image? Please provide the color name."
dataset.apply_model(zoo_model, label_field="vehicle_color")

# %% [markdown]
# You can also classify the location of the damage:

# %%
zoo_model.prompt = """You are required to report the location of vehicle damage. \
    List all the locations where this vehicle has been damaged. Choose from one or more of the following, or include any location not explicitly listed:
    - quarter panel
    - driver door
    - passenger door
    - rear door
    - hood
    - front bumper
    - rear bumper
    - quarter panel
    - tires
    - rim
    - wheel well
    - window
    - windshield

    Where all the locations where this vehicle has been damaged?"""

dataset.apply_model(zoo_model, label_field="damage_location")

# %% [markdown]
# Let's briefly explore what the VLM has come up with. For context, let's open the first image and examine the model output:

# %%
from PIL import Image

Image.open(dataset.first().filepath)

# %%
print(dataset.first().damage_report)

# %%
dataset.first().vehicle_color

# %%
dataset.first().damage_location

# %%
dataset.save()
dataset.persistent = True

# %% [markdown]
# Note, at this point it will be helpful for us to install the [Caption Viewer Plugin](https://github.com/mythrandire/caption-viewer) so that we can more easily read the captions as we explore them in the App.

# %%
# !fiftyone plugins download https://github.com/mythrandire/caption-viewer

# %%
fo.launch_app(dataset)

# %% [markdown]
# You can also refresh the FiftyOne App and view the model output for each sample in the Dataset.
#
# ## Your turn now!
#
# There are several VLMs which are integrated as remotely sourced zoo models.
#
# Pick from one (or more) of the following and see what you can get these models to do. Each of these repos has a complete notebook example and thorough README:
#
# - [Moondream2](https://github.com/harpreetsahota204/moondream2)
#
# - [Florence2](https://github.com/harpreetsahota204/florence2)
#
# - [PaliGemma2](https://github.com/harpreetsahota204/paligemma2)
#
# - [Qwen2.5-VL](https://github.com/harpreetsahota204/qwen2_5_vl)
#
# - [MiMo-VL](https://github.com/harpreetsahota204/MiMo_VL/)
#
# - [Kimi-VL](https://github.com/harpreetsahota204/Kimi_VL_A3B/)
#
# By the way, you may want to push your dataset to Hugging Face so that you can access it later.
#
# Make sure you have a Hugging Face token, and then sign in via the CLI: `huggingface-cli login` and enter your token.
#
# Once you've done that, you can push your dataset to the hub as follows:
#
# ```python
#
# from fiftyone.utils.huggingface import push_to_hub
#
# push_to_hub(
#     dataset,
#     "<some-repo-name>"
# )
# ```
